# %% [markdown]
# ## Optimal routing from stores having specific medicines available to the required address

# %%
from arcgis.gis import GIS
my_gis = GIS('home')

# %%
import arcgis
from arcgis.gis import GIS
import pandas as pd
import datetime
import getpass
from IPython.display import HTML
from IPython.display import FileLink, FileLinks

from arcgis import geocoding
from arcgis.features import Feature, FeatureSet
from arcgis.features import GeoAccessor, GeoSeriesAccessor

# %%
#customer data
customers_csv = "home/customers.csv"

# Read the csv file and convert the data to feature set
customers_df = pd.read_csv(customers_csv)
customers_sdf = pd.DataFrame.spatial.from_df(customers_df, "Address")
customers_fset = customers_sdf.spatial.to_featureset()

# %%
customers_sdf.head()
# Out:
#                                              Address  \
# 0  DADAR AVANTHI CHS, Vijay Nagar Building, 10, S...
# 1  802, Old Prabhadevi Rd, Prabhadevi, Mumbai, Ma...
# 2  1, Dr Baba Saheb Ambedkar Rd, near Premier Cin...
# 3  GD Ambedkar Marg Parel Tank Road Kalachowki Am...
# 4  Kalyandas Wadi, Shop No. 15, Dr Baba Saheb Amb...
#
#                                                SHAPE
# 0  {"x": 72.84650241600008, "y": 19.0283986920000...
# 1  {"x": 72.82391804000008, "y": 19.0134605920000...
# 2  {"x": 72.84235605600003, "y": 19.0099955950000...
# 3  {"x": 72.84682154500007, "y": 18.9968172060000...
# 4  {"x": 72.84465630200003, "y": 19.0137659430000...

# %%
#medical stores data
stores_csv = "home/stores.csv"

# Read the csv file and convert the data to feature set
stores_df = pd.read_csv(stores_csv)
stores_sdf = pd.DataFrame.spatial.from_xy(stores_df, "Longitude", "Latitude")
stores_sdf = stores_sdf.drop(axis=1, labels=["Longitude", "Latitude"])
stores_fset = stores_sdf.spatial.to_featureset()
stores_sdf
# Out:
#                               Name      Metformin  \
# 0    Sheth Medical & General Store      available
# 1    Ashok Medical & General Store      available
# 2          Jai Hind Medical Stores      available
# 3  Kalpana Medical & General Store  not available
# 4                 Ashapura Chemist      available
# 5  Roshani Medical & General Store  not available
# 6                       Sai Medico      available
#
#                                                SHAPE
# 0  {"spatialReference": {"wkid": 4326}, "x": 72.8...
# 1  {"spatialReference": {"wkid": 4326}, "x": 72.8...
# 2  {"spatialReference": {"wkid": 4326}, "x": 72.9...
# 3  {"spatialReference": {"wkid": 4326}, "x": 72.8...
# 4  {"spatialReference": {"wkid": 4326}, "x": 72.8...
# 5  {"spatialReference": {"wkid": 4326}, "x": 72.8...
# 6  {"spatialReference": {"wkid": 4326}, "x": 72.8...

# %%
# Create a map instance to visualize inputs in map
map_view_inputs = my_gis.map('Mumbai, Maharashtra, IND', zoomlevel=9)
map_view_inputs
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-402e1aca-48aa-42b4-a945-0d11c0fdf322"><img src=""></img></div>
# <div class="map-html-embed-preview-402e1aca-48aa-42b4-a945-0d11c0fdf322"></div>

# %%
# Visualize order and depot locations with symbology
map_view_inputs.draw(customers_fset, symbol={"type": "esriSMS","style": "esriSMSCircle","color": [76,115,0,255],"size": 8})
map_view_inputs.draw(stores_fset, symbol={"type": "esriSMS","style": "esriSMSSquare","color": [255,115,0,255], "size": 10})

# %%
#routes of all stores
testroutes_csv = "home/testroutes.csv"

# Read the csv file
testroutes_df = pd.read_csv(testroutes_csv, parse_dates=["EarliestStartTime", "LatestStartTime"], date_parser=pd.to_datetime)
testroutes_df["EarliestStartTime"] = testroutes_df["EarliestStartTime"].astype("int64") / 10 ** 6
testroutes_df["LatestStartTime"] = testroutes_df["LatestStartTime"].astype("int64") / 10 ** 6
testroutes_fset = arcgis.features.FeatureSet.from_dataframe(testroutes_df)
route_dummy = testroutes_df.set_index('Stores')
testroutes_df
# Out:
#    ObjectID                           Stores    Name  \
# 0         1    Sheth Medical & General Store  Route1
# 1         2    Ashok Medical & General Store  Route2
# 2         3          Jai Hind Medical Stores  Route3
# 3         4  Kalpana Medical & General Store  Route4
# 4         5                 Ashapura Chemist  Route5
# 5         6  Roshani Medical & General Store  Route6
# 6         7                       Sai Medico  Route7
#
#                     StartDepotName                     EndDepotName  \
# 0    Sheth Medical & General Store    Sheth Medical & General Store
# 1    Ashok Medical & General Store    Ashok Medical & General Store
# 2          Jai Hind Medical Stores          Jai Hind Medical Stores
# 3  Kalpana Medical & General Store  Kalpana Medical & General Store
# 4                 Ashapura Chemist                 Ashapura Chemist
# 5  Roshani Medical & General Store  Roshani Medical & General Store
# 6                       Sai Medico                       Sai Medico
#
#    EarliestStartTime  LatestStartTime  Capacities  CostPerUnitTime  \
# 0       1.637741e+12     1.637748e+12          10               20
# 1       1.637741e+12     1.637748e+12          10               20
# 2       1.637741e+12     1.637748e+12          10               20
# 3       1.637741e+12     1.637748e+12          10               20
# 4       1.637741e+12     1.637748e+12          10               20
# 5       1.637741e+12     1.637748e+12          10               20
# 6       1.637741e+12     1.637748e+12          10               20
#
#    MaxOrderCount  MaxTotalTime  AssignmentRule
# 0             10           360               1
# 1             10           360               1
# 2             10           360               1
# 3             10           360               1
# 4             10           360               1
# 5             10           360               1
# 6             10           360               1

# %%
#extract those stores where Metformin medicines are available
stores_med_df = stores_df.loc[stores_df['Metformin']=='available']
stores_med_sdf = pd.DataFrame.spatial.from_xy(stores_med_df, "Longitude", "Latitude")
stores_med_sdf = stores_med_sdf.drop(axis=1, labels=["Longitude", "Latitude"])
stores_med_fset = stores_med_sdf.spatial.to_featureset()
stores_med_sdf
# Out:
# /opt/conda/lib/python3.7/site-packages/arcgis/features/geo/_io/fileops.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SHAPE'] = GeoArray(ags_geom)
#                             Name  Metformin  \
# 0  Sheth Medical & General Store  available
# 1  Ashok Medical & General Store  available
# 2        Jai Hind Medical Stores  available
# 4               Ashapura Chemist  available
# 6                     Sai Medico  available
#
#                                                SHAPE
# 0  {"spatialReference": {"wkid": 4326}, "x": 72.8...
# 1  {"spatialReference": {"wkid": 4326}, "x": 72.8...
# 2  {"spatialReference": {"wkid": 4326}, "x": 72.9...
# 4  {"spatialReference": {"wkid": 4326}, "x": 72.8...
# 6  {"spatialReference": {"wkid": 4326}, "x": 72.8...

# %%
#download the dataset of medical stores where Metformin medicines are available
stores_med_df.to_csv('home/stores_med.csv', index=False)    #to download the csv file

FileLinks('home')
# Out:
# home/
#   .nb_auth_file
#   routes.csv
#   depots.csv
#   Routes_fset.json
#   orders.csv
#   customers.csv
#   stores.csv
#   testroutes.csv
#   routes_med.json
#   stores_med.csv
#   routes_med.csv
#   Routes_details.csv
#   Stops_details.csv
# home/pittsburgh_restaurants.gdb/
#   a00000001.gdbindexes
#   a00000001.gdbtable
#   a00000001.gdbtablx
#   a00000001.TablesByName.atx
#   a00000002.gdbtable
#   a00000002.gdbtablx
#   a00000003.gdbindexes
#   a00000003.gdbtable
#   a00000003.gdbtablx
#   a00000004.CatItemsByPhysicalName.atx
#   a00000004.CatItemsByType.atx
#   a00000004.FDO_UUID.atx
#   a00000004.gdbindexes
#   a00000004.gdbtable
#   a00000004.gdbtablx
#   a00000004.spx
#   a00000005.CatItemTypesByName.atx
#   a00000005.CatItemTypesByParentTypeID.atx
#   a00000005.CatItemTypesByUUID.atx
#   a00000005.gdbindexes
#   a00000005.gdbtable
#   a00000005.gdbtablx
#   a00000006.CatRelsByDestinationID.atx
#   a00000006.CatRelsByOriginID.atx
#   a00000006.CatRelsByType.atx
#   a00000006.FDO_UUID.atx
#   a00000006.gdbindexes
#   a00000006.gdbtable
#   a00000006.gdbtablx
#   a00000007.CatRelTypesByBackwardLabel.atx
#   a00000007.CatRelTypesByDestItemTypeID.atx
#   a00000007.CatRelTypesByForwardLabel.atx
#   a00000007.CatRelTypesByName.atx
#   a00000007.CatRelTypesByOriginItemTypeID.atx
#   a00000007.CatRelTypesByUUID.atx
#   a00000007.gdbindexes
#   a00000007.gdbtable
#   a00000007.gdbtablx
#   gdb
#   timestamps
#   _gdb.0b787b2bb5bf48a.9.8.sr.lock
#   a00000004.horizon
#   a00000009.gdbtable
#   a00000009.gdbtablx
#   a00000009.gdbindexes
#   a00000009.horizon
#   a00000009.spx
#   a00000001.freelist
#   a0000000b.gdbtable
#   a0000000b.gdbtablx
#   a0000000b.gdbindexes
#   a0000000b.horizon
#   a0000000b.spx
#   a0000000c.gdbtable
#   a0000000c.gdbtablx
#   a0000000c.gdbindexes
#   a0000000c.horizon
#   a00000004.freelist
#   a00000006.freelist
#   a0000000c.spx
#   a0000000d.gdbtable
#   a0000000d.gdbtablx
#   a0000000d.gdbindexes
#   a0000000d.horizon
#   a0000000d.spx

# %%
#stores' list where Metformin medicines are available
list_of_stores = stores_med_df['Name'].to_list()
list_of_stores
# Out:
# ['Sheth Medical & General Store',
#  'Ashok Medical & General Store',
#  'Jai Hind Medical Stores',
#  'Ashapura Chemist',
#  'Sai Medico']

# %%
#stores where Metformin medicines are not available
for index,row in route_dummy.iterrows():
  if index not in list_of_stores:
    print(str(index)  + ' is not having required medicines')
  else:
    pass
# Out:
# Kalpana Medical & General Store is not having required medicines
# Roshani Medical & General Store is not having required medicines

# %%
routes_updt = route_dummy[route_dummy.index.isin(list_of_stores)]
routes_df1 = routes_updt.reset_index()
routes_med_df = routes_df1.drop(['Stores'], axis = 1)
routes_med_df    #modified routes dataset where Metformin medicines are available
# Out:
#    ObjectID    Name                 StartDepotName  \
# 0         1  Route1  Sheth Medical & General Store
# 1         2  Route2  Ashok Medical & General Store
# 2         3  Route3        Jai Hind Medical Stores
# 3         5  Route5               Ashapura Chemist
# 4         7  Route7                     Sai Medico
#
#                     EndDepotName  EarliestStartTime  LatestStartTime  \
# 0  Sheth Medical & General Store       1.637741e+12     1.637748e+12
# 1  Ashok Medical & General Store       1.637741e+12     1.637748e+12
# 2        Jai Hind Medical Stores       1.637741e+12     1.637748e+12
# 3               Ashapura Chemist       1.637741e+12     1.637748e+12
# 4                     Sai Medico       1.637741e+12     1.637748e+12
#
#    Capacities  CostPerUnitTime  MaxOrderCount  MaxTotalTime  AssignmentRule
# 0          10               20             10           360               1
# 1          10               20             10           360               1
# 2          10               20             10           360               1
# 3          10               20             10           360               1
# 4          10               20             10           360               1

# %%
#download the modified route file
routes_med_df.to_csv('home/routes_med.csv', index=False)    #to download the csv file

FileLinks ('home')
# Out:
# home/
#   .nb_auth_file
#   routes.csv
#   depots.csv
#   Routes_fset.json
#   orders.csv
#   customers.csv
#   stores.csv
#   testroutes.csv
#   routes_med.json
#   stores_med.csv
#   routes_med.csv
#   Routes_details.csv
#   Stops_details.csv
# home/pittsburgh_restaurants.gdb/
#   a00000001.gdbindexes
#   a00000001.gdbtable
#   a00000001.gdbtablx
#   a00000001.TablesByName.atx
#   a00000002.gdbtable
#   a00000002.gdbtablx
#   a00000003.gdbindexes
#   a00000003.gdbtable
#   a00000003.gdbtablx
#   a00000004.CatItemsByPhysicalName.atx
#   a00000004.CatItemsByType.atx
#   a00000004.FDO_UUID.atx
#   a00000004.gdbindexes
#   a00000004.gdbtable
#   a00000004.gdbtablx
#   a00000004.spx
#   a00000005.CatItemTypesByName.atx
#   a00000005.CatItemTypesByParentTypeID.atx
#   a00000005.CatItemTypesByUUID.atx
#   a00000005.gdbindexes
#   a00000005.gdbtable
#   a00000005.gdbtablx
#   a00000006.CatRelsByDestinationID.atx
#   a00000006.CatRelsByOriginID.atx
#   a00000006.CatRelsByType.atx
#   a00000006.FDO_UUID.atx
#   a00000006.gdbindexes
#   a00000006.gdbtable
#   a00000006.gdbtablx
#   a00000007.CatRelTypesByBackwardLabel.atx
#   a00000007.CatRelTypesByDestItemTypeID.atx
#   a00000007.CatRelTypesByForwardLabel.atx
#   a00000007.CatRelTypesByName.atx
#   a00000007.CatRelTypesByOriginItemTypeID.atx
#   a00000007.CatRelTypesByUUID.atx
#   a00000007.gdbindexes
#   a00000007.gdbtable
#   a00000007.gdbtablx
#   gdb
#   timestamps
#   _gdb.0b787b2bb5bf48a.9.8.sr.lock
#   a00000004.horizon
#   a00000009.gdbtable
#   a00000009.gdbtablx
#   a00000009.gdbindexes
#   a00000009.horizon
#   a00000009.spx
#   a00000001.freelist
#   a0000000b.gdbtable
#   a0000000b.gdbtablx
#   a0000000b.gdbindexes
#   a0000000b.horizon
#   a0000000b.spx
#   a0000000c.gdbtable
#   a0000000c.gdbtablx
#   a0000000c.gdbindexes
#   a0000000c.horizon
#   a00000004.freelist
#   a00000006.freelist
#   a0000000c.spx
#   a0000000d.gdbtable
#   a0000000d.gdbtablx
#   a0000000d.gdbindexes
#   a0000000d.horizon
#   a0000000d.spx

# %%
#convert the modified route file to json file online and import it here
import json
with open("home/routes_med.json") as f:
    df1 = json.load(f)
routes_string = json.dumps(df1)    
routes_fset5 = FeatureSet.from_json(routes_string)
routes_fset5
# Out:
# <FeatureSet> 5 features

# %%
routes_string
# Out:
# '{"features": [{"attributes": {"Name": "Route1", "StartDepotName": "Sheth Medical & General Store", "EndDepotName": "Sheth Medical & General Store", "EarliestStartTime": "11/24/2021 8:00", "LatestStartTime": "11/24/2021 10:00", "Capacities": 10, "CostPerUnitTime": 20, "MaxOrderCount": 10, "MaxTotalTime": 360, "AssignmentRule": 1}}, {"attributes": {"Name": "Route2", "StartDepotName": "Ashok Medical & General Store", "EndDepotName": "Ashok Medical & General Store", "EarliestStartTime": "11/24/2021 8:00", "LatestStartTime": "11/24/2021 10:00", "Capacities": 10, "CostPerUnitTime": 20, "MaxOrderCount": 10, "MaxTotalTime": 360, "AssignmentRule": 1}}, {"attributes": {"Name": "Route3", "StartDepotName": "Jai Hind Medical Stores", "EndDepotName": "Jai Hind Medical Stores", "EarliestStartTime": "11/24/2021 8:00", "LatestStartTime": "11/24/2021 10:00", "Capacities": 10, "CostPerUnitTime": 20, "MaxOrderCount": 10, "MaxTotalTime": 360, "AssignmentRule": 1}}, {"attributes": {"Name": "Route5", "StartDepotName": "Ashapura Chemist", "EndDepotName": "Ashapura Chemist", "EarliestStartTime": "11/24/2021 8:00", "LatestStartTime": "11/24/2021 10:00", "Capacities": 10, "CostPerUnitTime": 20, "MaxOrderCount": 10, "MaxTotalTime": 360, "AssignmentRule": 1}}, {"attributes": {"Name": "Route7", "StartDepotName": "Sai Medico", "EndDepotName": "Sai Medico", "EarliestStartTime": "11/24/2021 8:00", "LatestStartTime": "11/24/2021 10:00", "Capacities": 10, "CostPerUnitTime": 20, "MaxOrderCount": 10, "MaxTotalTime": 360, "AssignmentRule": 1}}]}'

# %%
# %%time
today = datetime.datetime.now()
from arcgis.network.analysis import solve_vehicle_routing_problem
results = solve_vehicle_routing_problem(orders= customers_fset,
                                        depots = stores_med_fset,
                                        routes = routes_fset5, 
                                        save_route_data='true',
                                        populate_directions='true',
                                        travel_mode="Driving Time",
                                        default_date=today)

print('Analysis succeeded? {}'.format(results.solve_succeeded))
# Out:
# WARNING 030194: Data values longer than 500 characters for field [Routes:StartDepotName] are truncated.
# WARNING 030194: Data values longer than 500 characters for field [Routes:EndDepotName] are truncated.
# Network elements with avoid-restrictions are traversed in the output (restriction attribute names: "Avoid Private Roads" "Through Traffic Prohibited" "Avoid Gates").
# Analysis succeeded? True
# CPU times: user 248 ms, sys: 12.9 ms, total: 261 ms
# Wall time: 12.7 s

# %%
# Display the output routes in a pandas dataframe.
out_routes_df = results.out_routes.sdf
out_routes_df[['Name','OrderCount','StartTime','EndTime','TotalCost','TotalDistance','TotalTime','TotalTravelTime','StartTimeUTC','EndTimeUTC']]
# Out:
#      Name  OrderCount           StartTime                       EndTime  \
# 0  Route1           7 2021-11-24 08:00:00 2021-11-24 09:05:51.737999916
# 1  Route2           8 2021-11-24 08:00:00 2021-11-24 09:21:42.072999954
# 2  Route3           9 2021-11-24 08:00:00 2021-11-24 10:26:57.714999914
# 3  Route5           9 2021-11-24 08:00:00 2021-11-24 08:51:11.542999983
# 4  Route7           7 2021-11-24 08:00:00 2021-11-24 08:56:47.556999922
#
#      TotalCost  TotalDistance   TotalTime  TotalTravelTime  \
# 0  1317.246164      14.209776   65.862308        65.862308
# 1  1634.024264      19.500736   81.701213        81.701213
# 2  2939.238235      31.652198  146.961912       146.961912
# 3  1023.847758      10.330118   51.192388        51.192388
# 4  1135.852291      13.297972   56.792615        56.792615
#
#          StartTimeUTC                    EndTimeUTC
# 0 2021-11-24 02:30:00 2021-11-24 03:35:51.737999916
# 1 2021-11-24 02:30:00 2021-11-24 03:51:42.072999954
# 2 2021-11-24 02:30:00 2021-11-24 04:56:57.714999914
# 3 2021-11-24 02:30:00 2021-11-24 03:21:11.542999983
# 4 2021-11-24 02:30:00 2021-11-24 03:26:47.556999922

# %%
out_routes_df.to_csv('home/Routes_details.csv', index=False)    #to download the csv file

FileLinks ('home')
# Out:
# home/
#   .nb_auth_file
#   routes.csv
#   depots.csv
#   Routes_fset.json
#   orders.csv
#   customers.csv
#   stores.csv
#   testroutes.csv
#   routes_med.json
#   stores_med.csv
#   routes_med.csv
#   Routes_details.csv
#   Stops_details.csv
# home/pittsburgh_restaurants.gdb/
#   a00000001.gdbindexes
#   a00000001.gdbtable
#   a00000001.gdbtablx
#   a00000001.TablesByName.atx
#   a00000002.gdbtable
#   a00000002.gdbtablx
#   a00000003.gdbindexes
#   a00000003.gdbtable
#   a00000003.gdbtablx
#   a00000004.CatItemsByPhysicalName.atx
#   a00000004.CatItemsByType.atx
#   a00000004.FDO_UUID.atx
#   a00000004.gdbindexes
#   a00000004.gdbtable
#   a00000004.gdbtablx
#   a00000004.spx
#   a00000005.CatItemTypesByName.atx
#   a00000005.CatItemTypesByParentTypeID.atx
#   a00000005.CatItemTypesByUUID.atx
#   a00000005.gdbindexes
#   a00000005.gdbtable
#   a00000005.gdbtablx
#   a00000006.CatRelsByDestinationID.atx
#   a00000006.CatRelsByOriginID.atx
#   a00000006.CatRelsByType.atx
#   a00000006.FDO_UUID.atx
#   a00000006.gdbindexes
#   a00000006.gdbtable
#   a00000006.gdbtablx
#   a00000007.CatRelTypesByBackwardLabel.atx
#   a00000007.CatRelTypesByDestItemTypeID.atx
#   a00000007.CatRelTypesByForwardLabel.atx
#   a00000007.CatRelTypesByName.atx
#   a00000007.CatRelTypesByOriginItemTypeID.atx
#   a00000007.CatRelTypesByUUID.atx
#   a00000007.gdbindexes
#   a00000007.gdbtable
#   a00000007.gdbtablx
#   gdb
#   timestamps
#   _gdb.0b787b2bb5bf48a.9.8.sr.lock
#   a00000004.horizon
#   a00000009.gdbtable
#   a00000009.gdbtablx
#   a00000009.gdbindexes
#   a00000009.horizon
#   a00000009.spx
#   a00000001.freelist
#   a0000000b.gdbtable
#   a0000000b.gdbtablx
#   a0000000b.gdbindexes
#   a0000000b.horizon
#   a0000000b.spx
#   a0000000c.gdbtable
#   a0000000c.gdbtablx
#   a0000000c.gdbindexes
#   a0000000c.horizon
#   a00000004.freelist
#   a00000006.freelist
#   a0000000c.spx
#   a0000000d.gdbtable
#   a0000000d.gdbtablx
#   a0000000d.gdbindexes
#   a0000000d.horizon
#   a0000000d.spx

# %%
out_stops_df = results.out_stops.sdf
out_stops_df[['Name','RouteName','Sequence','ArriveTime','DepartTime']].sort_values(by=['RouteName',
                                                                                       'Sequence'])
# Out:
#                              Name RouteName  Sequence  \
# 40  Sheth Medical & General Store    Route1         1
# 39                    Location 40    Route1         2
# 8                      Location 9    Route1         3
# 37                    Location 38    Route1         4
# 9                     Location 10    Route1         5
# 35                    Location 36    Route1         6
# 36                    Location 37    Route1         7
# 10                    Location 11    Route1         8
# 41  Sheth Medical & General Store    Route1         9
# 42  Ashok Medical & General Store    Route2         1
# 2                      Location 3    Route2         2
# 4                      Location 5    Route2         3
# 5                      Location 6    Route2         4
# 3                      Location 4    Route2         5
# 1                      Location 2    Route2         6
# 19                    Location 20    Route2         7
# 0                      Location 1    Route2         8
# 16                    Location 17    Route2         9
# 43  Ashok Medical & General Store    Route2        10
# 44        Jai Hind Medical Stores    Route3         1
# 15                    Location 16    Route3         2
# 14                    Location 15    Route3         3
# 18                    Location 19    Route3         4
# 17                    Location 18    Route3         5
# 11                    Location 12    Route3         6
# 24                    Location 25    Route3         7
# 12                    Location 13    Route3         8
# 13                    Location 14    Route3         9
# 25                    Location 26    Route3        10
# 45        Jai Hind Medical Stores    Route3        11
# 46               Ashapura Chemist    Route5         1
# 30                    Location 31    Route5         2
# 27                    Location 28    Route5         3
# 33                    Location 34    Route5         4
# 20                    Location 21    Route5         5
# 32                    Location 33    Route5         6
# 28                    Location 29    Route5         7
# 29                    Location 30    Route5         8
# 31                    Location 32    Route5         9
# 34                    Location 35    Route5        10
# 47               Ashapura Chemist    Route5        11
# 48                     Sai Medico    Route7         1
# 26                    Location 27    Route7         2
# 23                    Location 24    Route7         3
# 22                    Location 23    Route7         4
# 38                    Location 39    Route7         5
# 6                      Location 7    Route7         6
# 7                      Location 8    Route7         7
# 21                    Location 22    Route7         8
# 49                     Sai Medico    Route7         9
#
#                       ArriveTime                    DepartTime
# 40 2021-11-24 08:00:00.000000000 2021-11-24 08:00:00.000000000
# 39 2021-11-24 08:05:23.861999989 2021-11-24 08:05:23.861999989
# 8  2021-11-24 08:13:00.239000082 2021-11-24 08:13:00.239000082
# 37 2021-11-24 08:19:55.713999987 2021-11-24 08:19:55.713999987
# 9  2021-11-24 08:24:39.727999926 2021-11-24 08:24:39.727999926
# 35 2021-11-24 08:34:23.125999928 2021-11-24 08:34:23.125999928
# 36 2021-11-24 08:37:37.372999907 2021-11-24 08:37:37.372999907
# 10 2021-11-24 08:53:07.697000027 2021-11-24 08:53:07.697000027
# 41 2021-11-24 09:05:51.737999916 2021-11-24 09:05:51.737999916
# 42 2021-11-24 08:00:00.000000000 2021-11-24 08:00:00.000000000
# 2  2021-11-24 08:07:15.973000050 2021-11-24 08:07:15.973000050
# 4  2021-11-24 08:08:58.313999891 2021-11-24 08:08:58.313999891
# 5  2021-11-24 08:14:52.559999943 2021-11-24 08:14:52.559999943
# 3  2021-11-24 08:21:01.180000067 2021-11-24 08:21:01.180000067
# 1  2021-11-24 08:31:46.908999920 2021-11-24 08:31:46.908999920
# 19 2021-11-24 08:41:08.062000036 2021-11-24 08:41:08.062000036
# 0  2021-11-24 08:42:20.046000004 2021-11-24 08:42:20.046000004
# 16 2021-11-24 09:03:18.530999899 2021-11-24 09:03:18.530999899
# 43 2021-11-24 09:21:42.072999954 2021-11-24 09:21:42.072999954
# 44 2021-11-24 08:00:00.000000000 2021-11-24 08:00:00.000000000
# 15 2021-11-24 08:25:56.661000013 2021-11-24 08:25:56.661000013
# 14 2021-11-24 08:44:04.543999910 2021-11-24 08:44:04.543999910
# 18 2021-11-24 09:01:02.247999907 2021-11-24 09:01:02.247999907
# 17 2021-11-24 09:09:33.394000053 2021-11-24 09:09:33.394000053
# 11 2021-11-24 09:34:06.707999945 2021-11-24 09:34:06.707999945
# 24 2021-11-24 09:50:05.733000040 2021-11-24 09:50:05.733000040
# 12 2021-11-24 10:00:19.596999884 2021-11-24 10:00:19.596999884
# 13 2021-11-24 10:09:04.799000025 2021-11-24 10:09:04.799000025
# 25 2021-11-24 10:22:03.322000027 2021-11-24 10:22:03.322000027
# 45 2021-11-24 10:26:57.714999914 2021-11-24 10:26:57.714999914
# 46 2021-11-24 08:00:00.000000000 2021-11-24 08:00:00.000000000
# 30 2021-11-24 08:04:11.194999933 2021-11-24 08:04:11.194999933
# 27 2021-11-24 08:09:44.552000046 2021-11-24 08:09:44.552000046
# 33 2021-11-24 08:17:03.721999884 2021-11-24 08:17:03.721999884
# 20 2021-11-24 08:21:52.325999975 2021-11-24 08:21:52.325999975
# 32 2021-11-24 08:29:50.622999907 2021-11-24 08:29:50.622999907
# 28 2021-11-24 08:37:33.822999954 2021-11-24 08:37:33.822999954
# 29 2021-11-24 08:40:36.368999958 2021-11-24 08:40:36.368999958
# 31 2021-11-24 08:43:56.430000067 2021-11-24 08:43:56.430000067
# 34 2021-11-24 08:45:58.020999908 2021-11-24 08:45:58.020999908
# 47 2021-11-24 08:51:11.542999983 2021-11-24 08:51:11.542999983
# 48 2021-11-24 08:00:00.000000000 2021-11-24 08:00:00.000000000
# 26 2021-11-24 08:08:45.299000025 2021-11-24 08:08:45.299000025
# 23 2021-11-24 08:11:59.579999924 2021-11-24 08:11:59.579999924
# 22 2021-11-24 08:20:18.595000029 2021-11-24 08:20:18.595000029
# 38 2021-11-24 08:26:28.052000046 2021-11-24 08:26:28.052000046
# 6  2021-11-24 08:39:19.618000031 2021-11-24 08:39:19.618000031
# 7  2021-11-24 08:41:24.246000051 2021-11-24 08:41:24.246000051
# 21 2021-11-24 08:51:03.183000088 2021-11-24 08:51:03.183000088
# 49 2021-11-24 08:56:47.556999922 2021-11-24 08:56:47.556999922

# %%
out_stops_df.to_csv('home/Stops_details.csv', index=False)    #to download the csv file

FileLinks ('home')
# Out:
# home/
#   .nb_auth_file
#   routes.csv
#   depots.csv
#   Routes_fset.json
#   orders.csv
#   customers.csv
#   stores.csv
#   testroutes.csv
#   routes_med.json
#   stores_med.csv
#   routes_med.csv
#   Routes_details.csv
#   Stops_details.csv
# home/pittsburgh_restaurants.gdb/
#   a00000001.gdbindexes
#   a00000001.gdbtable
#   a00000001.gdbtablx
#   a00000001.TablesByName.atx
#   a00000002.gdbtable
#   a00000002.gdbtablx
#   a00000003.gdbindexes
#   a00000003.gdbtable
#   a00000003.gdbtablx
#   a00000004.CatItemsByPhysicalName.atx
#   a00000004.CatItemsByType.atx
#   a00000004.FDO_UUID.atx
#   a00000004.gdbindexes
#   a00000004.gdbtable
#   a00000004.gdbtablx
#   a00000004.spx
#   a00000005.CatItemTypesByName.atx
#   a00000005.CatItemTypesByParentTypeID.atx
#   a00000005.CatItemTypesByUUID.atx
#   a00000005.gdbindexes
#   a00000005.gdbtable
#   a00000005.gdbtablx
#   a00000006.CatRelsByDestinationID.atx
#   a00000006.CatRelsByOriginID.atx
#   a00000006.CatRelsByType.atx
#   a00000006.FDO_UUID.atx
#   a00000006.gdbindexes
#   a00000006.gdbtable
#   a00000006.gdbtablx
#   a00000007.CatRelTypesByBackwardLabel.atx
#   a00000007.CatRelTypesByDestItemTypeID.atx
#   a00000007.CatRelTypesByForwardLabel.atx
#   a00000007.CatRelTypesByName.atx
#   a00000007.CatRelTypesByOriginItemTypeID.atx
#   a00000007.CatRelTypesByUUID.atx
#   a00000007.gdbindexes
#   a00000007.gdbtable
#   a00000007.gdbtablx
#   gdb
#   timestamps
#   _gdb.0b787b2bb5bf48a.9.8.sr.lock
#   a00000004.horizon
#   a00000009.gdbtable
#   a00000009.gdbtablx
#   a00000009.gdbindexes
#   a00000009.horizon
#   a00000009.spx
#   a00000001.freelist
#   a0000000b.gdbtable
#   a0000000b.gdbtablx
#   a0000000b.gdbindexes
#   a0000000b.horizon
#   a0000000b.spx
#   a0000000c.gdbtable
#   a0000000c.gdbtablx
#   a0000000c.gdbindexes
#   a0000000c.horizon
#   a00000004.freelist
#   a00000006.freelist
#   a0000000c.spx
#   a0000000d.gdbtable
#   a0000000d.gdbtablx
#   a0000000d.gdbindexes
#   a0000000d.horizon
#   a0000000d.spx

# %%
# Create a map instance to visualize outputs in map
map_view_outputs = my_gis.map('Mumbai, Maharashtra, IND', zoomlevel=9.5)
map_view_outputs
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-35cf233d-0474-448d-a2e3-6c0f62dde829"><img src=""></img></div>
# <div class="map-html-embed-preview-35cf233d-0474-448d-a2e3-6c0f62dde829"></div>

# %%
#Visusalize the inputsn with different symbols
map_view_outputs.draw(customers_fset, symbol={"type": "esriSMS",
                                           "style": "esriSMSCircle",
                                           "color": [76,115,0,255],"size": 8})
map_view_outputs.draw(stores_med_fset, symbol={"type": "esriSMS",
                                           "style": "esriSMSSquare",
                                           "color": [255,115,0,255], "size": 10})

#Visualize the first route
out_routes_flist = []
out_routes_flist.append(results.out_routes.features[0])
out_routes_fset = []
out_routes_fset = FeatureSet(out_routes_flist)
map_view_outputs.draw(out_routes_fset, 
                      symbol={"type": "esriSLS",
                              "style": "esriSLSSolid",
                              "color":[0,100,240,255],"size":10})


#Visualize the second route
out_routes_flist = []
out_routes_flist.append(results.out_routes.features[1])
out_routes_fset = []
out_routes_fset = FeatureSet(out_routes_flist)
map_view_outputs.draw(out_routes_fset, 
                      symbol={"type": "esriSLS",
                              "style": "esriSLSSolid",
                              "color": [255,0,0,255],"size":10})
#Visualize the third route
out_routes_flist = []
out_routes_flist.append(results.out_routes.features[2])
out_routes_fset = []
out_routes_fset = FeatureSet(out_routes_flist)
map_view_outputs.draw(out_routes_fset, 
                      symbol={"type": "esriSLS",
                              "style": "esriSLSSolid",
                              "color": [180,40,160,255],"size":10})
#Visualize the fifth route
out_routes_flist = []
out_routes_flist.append(results.out_routes.features[3])
out_routes_fset = []
out_routes_fset = FeatureSet(out_routes_flist)
map_view_outputs.draw(out_routes_fset, 
                      symbol={"type": "esriSLS",
                              "style": "esriSLSSolid",
                              "color": [20,40,80,255],"size":10})
#Visualize the seventh route
out_routes_flist = []
out_routes_flist.append(results.out_routes.features[4])
out_routes_fset = []
out_routes_fset = FeatureSet(out_routes_flist)
map_view_outputs.draw(out_routes_fset, 
                      symbol={"type": "esriSLS",
                              "style": "esriSLSSolid",
                              "color": [80,50,30,255],"size":10})

# %%
route_data = results.out_route_data.download('.')
route_data
# Out:
# './_ags_rda442642ef5374616a75844a51e0c6e59.zip'

# %%
route_data_item = my_gis.content.add({"type": "File Geodatabase"}, route_data)
route_data_item
# Out:
# <Item title:"_ags_rda442642ef5374616a75844a51e0c6e59" type:File Geodatabase owner:Mainak_CSRE_User>

# %%
route_layers = arcgis.features.analysis.create_route_layers(route_data_item, 
                                                            delete_route_data_item=True)
for route_layer in route_layers:
    route_layer.share(org=True)
    display(route_layer.homepage)
    display(route_layer)
# Out:
# 'https://www.arcgis.com/home/item.html?id=7083380ee3a74721a887ef0cf3aa1d1e'
# <Item title:"Route1" type:Feature Collection owner:Mainak_CSRE_User>
# 'https://www.arcgis.com/home/item.html?id=74a35bc8e7ce4687a3cfc89ab3b4822c'
# <Item title:"Route2" type:Feature Collection owner:Mainak_CSRE_User>
# 'https://www.arcgis.com/home/item.html?id=a9bc6d49338c44bb8317aef084abd984'
# <Item title:"Route3" type:Feature Collection owner:Mainak_CSRE_User>
# 'https://www.arcgis.com/home/item.html?id=da25295336d549e08b544ef3cb628e00'
# <Item title:"Route5" type:Feature Collection owner:Mainak_CSRE_User>
# 'https://www.arcgis.com/home/item.html?id=51220340017e462c9c37bf8c81b3dfb2'
# <Item title:"Route7" type:Feature Collection owner:Mainak_CSRE_User>
